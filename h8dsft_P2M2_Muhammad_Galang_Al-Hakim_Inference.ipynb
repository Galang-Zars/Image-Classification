# %% [markdown]
# # Model Inference

# %%
import numpy as np
import matplotlib.pyplot as plt
from tensorflow import keras
from PIL import Image
import tensorflow as tf
import joblib

# %%
with open('class_names.pkl','rb') as file_1:
  class_names = joblib.load(file_1)

# %%
# Load the trained model
model = keras.models.load_model(r"C:\Users\Galang\Documents\H8\ML\P2M2\best_model.h5")

# Define the target image size
img_height, img_width = 224, 224

# Upload the image file
uploaded_file = (r"C:\Users\Galang\Documents\H8\ML\P2M2\ANJING LU.jpg")

# Load and display the image
img = Image.open(uploaded_file).resize((img_height, img_width))
plt.imshow(img)
plt.axis('off')
plt.show()

img1 = keras.preprocessing.image.load_img(
    uploaded_file, target_size=(224,224))

img_array = keras.preprocessing.image.img_to_array(img)
img_array = tf.expand_dims(img_array, 0)

predictions = model.predict(img_array)
score = tf.nn.softmax(predictions[0])

print(
    "This image most likely belongs to {} with a {:.2f} percent confidence."
    .format(class_names[np.argmax(score)], 100 * np.max(score))
)
# Out:
# 1/1 [==============================] - 1s 846ms/step
# This image most likely belongs to anjing with a 23.20 percent confidence.

# %%
# Load the trained model
model = keras.models.load_model(r"C:\Users\Galang\Documents\H8\ML\P2M2\best_model.h5")

# Define the target image size
img_height, img_width = 224, 224

# Upload the image file
uploaded_file = (r"C:\Users\Galang\Documents\H8\ML\P2M2\KUPU KUPU MALAM.png")

# Load and display the image
img = Image.open(uploaded_file).resize((img_height, img_width))
plt.imshow(img)
plt.axis('off')
plt.show()

img1 = keras.preprocessing.image.load_img(
    uploaded_file, target_size=(224,224))

img_array = keras.preprocessing.image.img_to_array(img)
img_array = tf.expand_dims(img_array, 0)

predictions = model.predict(img_array)
score = tf.nn.softmax(predictions[0])

print(
    "This image most likely belongs to {} with a {:.2f} percent confidence."
    .format(class_names[np.argmax(score)], 100 * np.max(score))
)
# Out:
# 1/1 [==============================] - 1s 851ms/step
# This image most likely belongs to kupu-kupu with a 23.20 percent confidence.
